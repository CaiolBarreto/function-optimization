# %% [markdown]
# ### Imports

# %%
from functions import *
from GeneticAlgorithm import genetic_algorithm
from EvolutionaryAlgorithm import evolution_strategy
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ### Constants

# %%
POPULATION_SIZE = 50
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1
DIMENSIONS = 30
NUMBER_OF_EXECUTIONS = 5

# %% [markdown]
# ### Implementations

# %% [markdown]
# #### Ackley Function

# %%
min_value, max_value = -32.768, 32.768
ackley_min_values_genetic = []
ackley_min_values_evolutionary = []
params = {
    "pop_size": POPULATION_SIZE,
    "num_generations": NUM_GENERATIONS,
    "mutation_rate": MUTATION_RATE,
    "dimensions": DIMENSIONS,
    "min_value": min_value,
    "max_value": max_value,
    "current_function": ackley_function,
}

# %% [markdown]
# - ##### Algoritmo Genético

# %%
lower_min_global = float('inf')
lower_min_fitness_ga = []
executions_ga = []

for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ga = genetic_algorithm(**params)
   ackley_min_values_genetic.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ga = best_generations_ga

   executions_ga.append(best_generations_ga)
# Out:
# Global Minimum Value: 20.891764645101194
# Global Minimum Value: 20.579850914909137
# Global Minimum Value: 20.609870326829803
# Global Minimum Value: 20.688642984765597
# Global Minimum Value: 20.539270737507064

# %% [markdown]
# - ##### Algoritmo Evolutivo

# %%
lower_min_global = float('inf')
lower_min_fitness_ee = []
executions_ee = []

for i in range(NUMBER_OF_EXECUTIONS):
    global_min_value, best_generations_ee = evolution_strategy(**params)
    ackley_min_values_evolutionary.append(global_min_value)

    if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ee = best_generations_ee

    executions_ee.append(best_generations_ee)
# Out:
# Global Minimum Value: 20.57733070271089
# Global Minimum Value: 20.604353918662103
# Global Minimum Value: 20.787140953237756
# Global Minimum Value: 20.638380649923114
# Global Minimum Value: 20.924819316859445

# %% [markdown]
# - ##### Graphs

# %%
axis_value = [num for num in range(1, NUM_GENERATIONS + 1)]

# primeiro grafico
plt.figure()
plt.plot(axis_value, lower_min_fitness_ga, label="GA")
plt.plot(axis_value, lower_min_fitness_ee, label="EE")

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.legend() 
plt.title("GA vs EE (melhor execução)")

# segundo grafico
plt.figure()
for execution in executions_ga:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("GA em cada execução")

# terceiro grafico
plt.figure()
for execution in executions_ee:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("EE em cada execução")

plt.show()

# %% [markdown]
# Results Comparison

# %%
print("***** ACKLEY FUNCTION COMPARISON *****")
print('Global min value (Evolutionary): ', min(ackley_min_values_evolutionary))
print('Global min value mean (Evolutionary): ', numpy.mean(ackley_min_values_evolutionary))
print('\n')
print('Global min value (Genetic): ', min(ackley_min_values_genetic))
print('Global min value mean (Genetic): ', numpy.mean(ackley_min_values_genetic))
# Out:
# ***** ACKLEY FUNCTION COMPARISON *****
# Global min value (Evolutionary):  20.57733070271089
# Global min value mean (Evolutionary):  20.70640510827866
#
#
# Global min value (Genetic):  20.539270737507064
# Global min value mean (Genetic):  20.66187992182256

# %% [markdown]
# #### Rastrigin function

# %%
min_value, max_value = -5.12, 5.12
rastrigin_min_values_genetic = []
rastrigin_min_values_evolutionary = []
params = {
    "pop_size": POPULATION_SIZE,
    "num_generations": NUM_GENERATIONS,
    "mutation_rate": MUTATION_RATE,
    "dimensions": DIMENSIONS,
    "min_value": min_value,
    "max_value": max_value,
    "current_function": rastrigin_function,
}

# %% [markdown]
# - ##### Algoritmo Genético

# %%
lower_min_global = float('inf')
lower_min_fitness_ga = []
executions_ga = []


for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ga = genetic_algorithm(**params)
   rastrigin_min_values_genetic.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ga = best_generations_ga
   
   executions_ga.append(best_generations_ga)
# Out:
# Global Minimum Value: 366.86608496506597
# Global Minimum Value: 410.85932464035886
# Global Minimum Value: 401.1677551137285
# Global Minimum Value: 381.31461576221767
# Global Minimum Value: 359.1321392078401

# %% [markdown]
# - ##### Algoritmo Evolutivo

# %%
lower_min_global = float('inf')
lower_min_fitness_ee = []
executions_ee = []


for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ee = evolution_strategy(**params)
   rastrigin_min_values_evolutionary.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ee = best_generations_ee

   executions_ee.append(best_generations_ee)
# Out:
# Global Minimum Value: 442.72931808123735
# Global Minimum Value: 446.8905638358617
# Global Minimum Value: 437.85076655182
# Global Minimum Value: 428.79847097747995
# Global Minimum Value: 424.1031118957475

# %% [markdown]
# - ##### Graphs

# %%
axis_value = [num for num in range(1, NUM_GENERATIONS + 1)]

# primeiro grafico
plt.figure()
plt.plot(axis_value, lower_min_fitness_ga, label="GA")
plt.plot(axis_value, lower_min_fitness_ee, label="EE")

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.legend() 
plt.title("GA vs EE (melhor execução)")

# segundo grafico
plt.figure()
for execution in executions_ga:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("GA em cada execução")

# terceiro grafico
plt.figure()
for execution in executions_ee:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("EE em cada execução")

plt.show()

# %% [markdown]
# Results Comparison

# %%
print("***** RASTRIGIN FUNCTION COMPARISON *****")
print('Global min value (Evolutionary): ', min(rastrigin_min_values_evolutionary))
print('Global min value mean(Evolutionary): ', numpy.mean(rastrigin_min_values_evolutionary))
print('\n')
print('Global min value (Genetic): ', min(rastrigin_min_values_genetic))
print('Global min value mean (Genetic): ', numpy.mean(rastrigin_min_values_genetic))
# Out:
# ***** RASTRIGIN FUNCTION COMPARISON *****
# Global min value (Evolutionary):  424.1031118957475
# Global min value mean(Evolutionary):  436.07444626842937
#
#
# Global min value (Genetic):  359.1321392078401
# Global min value mean (Genetic):  383.86798393784227

# %% [markdown]
# #### Schwefel function

# %%
min_value, max_value = -500, 500
schwefel_min_values_genetic = []
schwefel_min_values_evolutionary = []
params = {
    "pop_size": POPULATION_SIZE,
    "num_generations": NUM_GENERATIONS,
    "mutation_rate": MUTATION_RATE,
    "dimensions": DIMENSIONS,
    "min_value": min_value,
    "max_value": max_value,
    "current_function": schwefel_function,
}

# %% [markdown]
# - ##### Algoritmo Genético

# %%
lower_min_global = float('inf')
lower_min_fitness_ga = []
executions_ga = []


for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ga = genetic_algorithm(**params)
   schwefel_min_values_genetic.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ga = best_generations_ga

   executions_ga.append(best_generations_ga)
# Out:
# Global Minimum Value: 9402.446925917722
# Global Minimum Value: 9342.573653084992
# Global Minimum Value: 9338.4755179579
# Global Minimum Value: 10102.815614322091
# Global Minimum Value: 8856.720470323045

# %% [markdown]
# - ##### Algoritmo Evolutivo

# %%
lower_min_global = float('inf')
lower_min_fitness_ee = []
executions_ee = []


for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ee = evolution_strategy(**params)
   schwefel_min_values_evolutionary.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ee = best_generations_ee

   executions_ee.append(best_generations_ee)
# Out:
# Global Minimum Value: 10720.279091240018
# Global Minimum Value: 10209.181315277769
# Global Minimum Value: 10456.928329913097
# Global Minimum Value: 10615.55212090306
# Global Minimum Value: 10717.495441127969

# %% [markdown]
# - ##### Graphs

# %%
axis_value = [num for num in range(1, NUM_GENERATIONS + 1)]

# primeiro grafico
plt.figure()
plt.plot(axis_value, lower_min_fitness_ga, label="GA")
plt.plot(axis_value, lower_min_fitness_ee, label="EE")

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.legend() 
plt.title("GA vs EE (melhor execução)")

# segundo grafico
plt.figure()
for execution in executions_ga:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("GA em cada execução")

# terceiro grafico
plt.figure()
for execution in executions_ee:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("EE em cada execução")

plt.show()

# %% [markdown]
# Results Comparison

# %%
print("***** SCHWEFEL FUNCTION COMPARISON *****")
print('Global min value (Evolutionary): ', min(schwefel_min_values_evolutionary))
print('Global min value mean (Evolutionary): ', numpy.mean(schwefel_min_values_evolutionary))
print('\n')
print('Global min value (Genetic): ', min(schwefel_min_values_genetic))
print('Global min value mean (Genetic): ', numpy.mean(schwefel_min_values_genetic))
# Out:
# ***** SCHWEFEL FUNCTION COMPARISON *****
# Global min value (Evolutionary):  10209.181315277769
# Global min value mean (Evolutionary):  10543.887259692383
#
#
# Global min value (Genetic):  8856.720470323045
# Global min value mean (Genetic):  9408.60643632115

# %% [markdown]
# #### Rosenbrock function

# %%
min_value, max_value = -5, 10
rosenbrock_min_values_genetic = []
rosenbrock_min_values_evolutionary = []
params = {
    "pop_size": POPULATION_SIZE,
    "num_generations": NUM_GENERATIONS,
    "mutation_rate": MUTATION_RATE,
    "dimensions": DIMENSIONS,
    "min_value": min_value,
    "max_value": max_value,
    "current_function": rosenbrock_function,
}

# %% [markdown]
# - ##### Algoritmo Genético

# %%
lower_min_global = float('inf')
lower_min_fitness_ga = []
executions_ga = []



for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ga = genetic_algorithm(**params)
   rosenbrock_min_values_genetic.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ga = best_generations_ga

   executions_ga.append(best_generations_ga)
# Out:
# Global Minimum Value: 222926.6933455056
# Global Minimum Value: 258309.58215075577
# Global Minimum Value: 185562.72384747275
# Global Minimum Value: 176493.73401899752
# Global Minimum Value: 130990.27299281409

# %% [markdown]
# - ##### Algoritmo Evolutivo

# %%
lower_min_global = float('inf')
lower_min_fitness_ee = []
executions_ee = []


for i in range(NUMBER_OF_EXECUTIONS):
   global_min_value, best_generations_ee = evolution_strategy(**params)
   rosenbrock_min_values_evolutionary.append(global_min_value)

   if global_min_value < lower_min_global:
      lower_min_global = global_min_value
      lower_min_fitness_ee = best_generations_ee

   executions_ee.append(best_generations_ee)
# Out:
# Global Minimum Value: 1114271.2539046027
# Global Minimum Value: 1743127.6415219805
# Global Minimum Value: 1040518.9026402661
# Global Minimum Value: 1851991.9544538315
# Global Minimum Value: 1574343.8072140734

# %% [markdown]
# - ##### Graphs

# %%
axis_value = [num for num in range(1, NUM_GENERATIONS + 1)]

# primeiro grafico
plt.figure()
plt.plot(axis_value, lower_min_fitness_ga, label="GA")
plt.plot(axis_value, lower_min_fitness_ee, label="EE")

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.legend()
plt.title("GA vs EE (melhor execução)")

# segundo grafico
plt.figure()
for execution in executions_ga:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("GA em cada execução")

# terceiro grafico
plt.figure()
for execution in executions_ee:
  plt.plot(axis_value, execution, alpha=0.5)

plt.xlabel('Gerações')
plt.ylabel('Mínimo da função')
plt.title("EE em cada execução")

plt.show()

# %% [markdown]
# Results Comparison

# %%
print("***** ROSENBROCK FUNCTION COMPARISON *****")
print('Global min value (Evolutionary): ', min(rosenbrock_min_values_evolutionary))
print('Global min value mean (Evolutionary): ', numpy.mean(rosenbrock_min_values_evolutionary))
print('\n')
print('Global min value (Genetic): ', min(rosenbrock_min_values_genetic))
print('Global min value mean (Genetic): ', numpy.mean(rosenbrock_min_values_genetic))
# Out:
# ***** ROSENBROCK FUNCTION COMPARISON *****
# Global min value (Evolutionary):  1040518.9026402661
# Global min value mean (Evolutionary):  1464850.7119469508
#
#
# Global min value (Genetic):  130990.27299281409
# Global min value mean (Genetic):  194856.60127110913
